# %%
from langchain_ollama import ChatOllama

# %%
llm=ChatOllama(model="phi3:3.8b")

# %%
res=llm.invoke("hello i am ashu")

# %%
res.content
# Out:
# 'Hello! How can I help you today? If there\'s anything specific on your mind, feel free to share. As for the text "ashu", it looks like a name in Hindi which means \'holy\'. Is this related to what we\'re discussing or is there another context here that you need assistance with regarding someone named Ashu?'
