# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm=ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    )

# %%
# Out:
# `map()` and `filter()` are two of the most commonly used higher-order array methods in JavaScript, and while they both iterate over an array and return a new array, they serve fundamentally different purposes.
#
# Let's break down each one:
#
# ---
#
# ## `Array.prototype.map()`
#
# ### Purpose
# The `map()` method is used to **transform** each element in an array and create a **new array** containing the results of applying a provided function to every element in the calling array.
#
# ### Key Characteristics
# 1.  **Transformation:** It changes each item into something else.
# 2.  **New Array:** It always returns a brand new array.
# 3.  **Same Length:** The new array will always have the **same number of elements** as the original array.
# 4.  **Callback Return Value:** The value returned by the callback function for each element becomes the corresponding element in the new array.
#
# ### Syntax
# ```javascript
# array.map(callback(currentValue, index, array))
# ```
#
# ### Example
# Let's say you have an array of numbers and you want to double each one.
#
# ```javascript
# const numbers = [1, 2, 3, 4, 5];
#
# const doubledNumbers = numbers.map(num => num * 2);
#
# console.log(doubledNumbers); // Output: [2, 4, 6, 8, 10]
# console.log(numbers);       // Original array remains unchanged: [1, 2, 3, 4, 5]
# ```
#
# **Another Example (Transforming Objects):**
#
# ```javascript
# const users = [
#   { id: 1, name: 'Alice', isActive: true },
#   { id: 2, name: 'Bob', isActive: false },
#   { id: 3, name: 'Charlie', isActive: true }
# ];
#
# // Get an array of just the user names
# const userNames = users.map(user => user.name);
# console.log(userNames); // Output: ["Alice", "Bob", "Charlie"]
#
# // Get an array of user IDs
# const userIds = users.map(user => user.id);
# console.log(userIds); // Output: [1, 2, 3]
# ```
#
# ---
#
# ## `Array.prototype.filter()`
#
# ### Purpose
# The `filter()` method is used to **select** a subset of elements from an array based on a provided condition. It creates a **new array** containing only the elements for which the provided callback function returns `true`.
#
# ### Key Characteristics
# 1.  **Selection/Filtering:** It keeps or discards elements based on a test.
# 2.  **New Array:** It always returns a brand new array.
# 3.  **Same or Shorter Length:** The new array will have **equal or fewer elements** than the original array. It will never be longer.
# 4.  **Callback Return Value:** The callback function must return a `boolean` value (`true` to keep the element, `false` to discard it).
#
# ### Syntax
# ```javascript
# array.filter(callback(currentValue, index, array))
# ```
#
# ### Example
# Let's say you have an array of numbers and you want to keep only the even ones.
#
# ```javascript
# const numbers = [1, 2, 3, 4, 5, 6];
#
# const evenNumbers = numbers.filter(num => num % 2 === 0);
#
# console.log(evenNumbers); // Output: [2, 4, 6]
# console.log(numbers);     // Original array remains unchanged: [1, 2, 3, 4, 5, 6]
# ```
#
# **Another Example (Filtering Objects):**
#
# ```javascript
# const users = [
#   { id: 1, name: 'Alice', isActive: true },
#   { id: 2, name: 'Bob', isActive: false },
#   { id: 3, name: 'Charlie', isActive: true }
# ];
#
# // Get an array of active users
# const activeUsers = users.filter(user => user.isActive);
# console.log(activeUsers);
# /* Output:
# [
#   { id: 1, name: 'Alice', isActive: true },
#   { id: 3, name: 'Charlie', isActive: true }
# ]
# */
#
# // Get users with IDs greater than 1
# const usersWithIdGreaterThanOne = users.filter(user => user.id > 1);
# console.log(usersWithIdGreaterThanOne);
# /* Output:
# [
#   { id: 2, name: 'Bob', isActive: false },
#   { id: 3, name: 'Charlie', isActive: true }
# ]
# */
# ```
#
# ---
#
# ## Core Differences Summarized
#
# | Feature             | `map()`                                      | `filter()`                                   |
# | :------------------ | :------------------------------------------- | :------------------------------------------- |
# | **Purpose**         | **Transform** each element                   | **Select** elements based on a condition     |
# | **Result Array**    | A new array with **transformed elements**    | A new array with elements that **pass the condition** |
# | **Array Length**    | Always the **same** as the original array    | Can be the **same or shorter** than the original array |
# | **Callback Return** | The **new value** for the element (can be anything) | A **boolean** (`true` to keep, `false` to discard) |
#
# ---
#
# ## When to Use Which
#
# *   **Use `map()` when:**
#     *   You need to change the *form* or *value* of each item in an array.
#     *   You want to create a new array where each element is the result of calling a function on the corresponding element in the original array.
#     *   Examples: Doubling numbers, extracting specific properties from an array of objects, converting data types.
#
# *   **Use `filter()` when:**
#     *   You need to *remove* certain items from an array based on a condition.
#     *   You want to create a new array containing only the elements that meet specific criteria.
#     *   Examples: Getting all even numbers, finding all active users, selecting items within a certain price range.
#
# Both `map()` and `filter()` are essential tools for working with arrays in a functional and immutable way in JavaScript, as they both return new arrays without modifying the original.

# %%
prompts=[
    {"role":"system", "content":"You are a javaScript Developer"},
    {"role":"user","content":"Diffrence between map and filter ?"}
]
res=llm.invoke(prompts)
print(res.content)

# %%
prompts=[
    {"role":"system", "content":"You are a translator and translate input in Hindi"},
    {"role":"user","content":"I love to play cricket"}
]
res=llm.invoke(prompts)
print(res.content)
# Out:
# मुझे क्रिकेट खेलना बहुत पसंद है।

# %%
##### Dynamic Prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")
out=StrOutputParser()

# %% [markdown]
# Self Chain Node

# %%
def transform_upper(res):
    return res.upper()

# %%
prompts=ChatPromptTemplate.from_messages([
    {"role":"system", "content":"You are a translator and translate input in {language}"},
    {"role":"user","content":"{query}"}
])
prompts
# Out:
# ChatPromptTemplate(input_variables=['language', 'query'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='You are a translator and translate input in {language}'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], input_types={}, partial_variables={}, template='{query}'), additional_kwargs={})])

# %% [markdown]
# ###prompt chaining

# %%
final_prompts=prompts.format_messages(language= "Hinglish",
                                      query="I love coding")
res=llm.invoke(final_prompts)
print(res.content)
# Out:
# Mujhe coding pasand hai.

# %%
res=llm.invoke(prompts.invoke({"language":"Hindi","query":"New Query"}))
res.content
# Out:
# 'नई क्वेरी'

# %%
chains=prompts|llm|out|transform_upper

# %%
res=chains.invoke({"language":"Hinglish","query":"Good Morning"})
print(res)
# Out:
# GOOD MORNING (शुभ प्रभात)
