# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
res=llm.invoke("Hello, My name is Mr.Someone")
res.content
# Out:
# "Hello Mr. Someone! It's a pleasure to meet you.\n\nHow can I help you today?"

# %%
res=llm.invoke("what is my name")
res.content
# Out:
# "I don't know your name. As an AI, I don't have access to personal information about you unless you've explicitly told it to me during our current conversation.\n\nIf you'd like to tell me your name, I can remember it for the duration of our chat!"

# %% [markdown]
# here llm dosen't have memory

# %%
prompts=[
    {"role":"user", "content":"hello my name is mr. someone"},
    {"role":"ai", "content":"hello, mr. someone how can i help you"},
    {"role":"user", "content":"what is my name"},
]

res=llm.invoke(prompts)
res.content
# Out:
# 'Your name is **mr. someone**.'

# %% [markdown]
# Manage History

# %%
history=[]
while True:
        
        query=input("User: ")
        if query.lower() in ["exit", "quit","bye"]:
                print("👋 Good Bye")
                break
        
        history.append({"role":"user","content":query})
        print("User: ", query)

        res=llm.invoke(history)
        history.append({"role":"ai","content":res.content})

        print("AI:",res.content, "/n")
# Out:
# User:  hello
# AI Hello! How can I help you today? /n
# User:  my name is Mr. Nobody
# AI It's nice to meet you, Mr. Nobody. Is there anything I can assist you with? /n
# User:  what is my name
# AI Your name is Mr. Nobody. /n
# 👋 Good Bye
