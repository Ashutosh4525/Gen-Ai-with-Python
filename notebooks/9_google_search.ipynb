# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#same
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
# 10lect changes
from langgraph.checkpoint.memory import MemorySaver

# %%
#same
model=ChatGroq(model="openai/gpt-oss-20b")
search=GoogleSerperAPIWrapper()

# %%
search.run("what is genai")
# Out:
# "Generative artificial intelligence, also known as generative AI or GenAI, is a subfield of artificial intelligence that uses generative models to generate text ... Generative AI is artificial intelligence (AI) that can create original content in response to a user's prompt or request. Generative artificial intelligence, unlike its predecessors, can create new content by extrapolating from its training data. Its extraordinary ability to ... Generative AI (GenAI) is a specialised form that creates new content- text, images, video, audio, or code, based on prompts and patterns in ... Generative AI, or GenAI, is a form of artificial intelligence that creates new content by learning patterns from existing data. Generative AI is a type of artificial intelligence tool that generates images, text, videos, and other media in response to inputted prompts ... Generative AI (GenAI) is a general term for artificial intelligence that creates new content by generating new data samples that are similar to the training ... it's a type of artificial intelligence that can create content—be it text, images, music, or even code—based on the information it's given ... Generative AI (GenAI) is a branch of artificial intelligence that mimics human creativity to generate original content in response to a user request. Generative AI (GenAI) consumes existing data, learns from it, then generates data with similar characteristics. For example, it can generate text, images, ..."

# %%
agent=create_agent(
    model=model,
    tools=[search.run],
    system_prompt="You are agent that search from Google",
    # new
    checkpointer=MemorySaver()
)

# %%
question="who won the women world cup"

# %%
response=agent.invoke({"messages":[{"role":"user","content":question}]},
                      {"configurable":{"thread_id":"1"}},
                      )

# %%
response["messages"][-1].content
# Out:
# 'The most recent FIFA Women’s World Cup (2023) was won by **Spain**. They defeated England 1–0 in the final held at Stadium Australia in Sydney to claim their first Women’s World Cup title.'
